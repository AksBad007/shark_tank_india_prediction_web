# %%
#imports

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import pickle

# %%
#load dataset

dataset = pd.read_csv('Shark_Tank_India_all_s1_s2_combined.csv')
dataset = dataset.rename(columns=lambda x: x.strip().lower())
dataset = dataset.set_index('id')

dataset = dataset[[
    'industry',
    'yearly revenue',
    'monthly sales',
    'gross margin',
    'net margin',
    'original ask amount',
    'original offered equity',
    'valuation requested',
    'has patents',
    'number of sharks in deal',
    'ashneer investment amount',
    'aman investment amount',
    'anupam investment amount',
    'namita investment amount',
    'vineeta investment amount',
    'ghazal investment amount',
    'peyush investment amount',
    'amit investment amount',
]]
dataset.head()
# Out:
#                         industry  yearly revenue  monthly sales  gross margin  \
# id
# 1                           Food            95.0            8.0           NaN
# 2   Vehicles/Electrical Vehicles             4.0            0.4           NaN
# 3                 Beauty/Fashion             NaN            2.0           NaN
# 4                           Food           700.0            NaN          48.0
# 5                      Education            30.0            NaN           NaN
#
#     net margin  original ask amount  original offered equity  \
# id
# 1          NaN                 50.0                      5.0
# 2          NaN                 40.0                     15.0
# 3          NaN                 25.0                     10.0
# 4          NaN                 70.0                      1.0
# 5          NaN                 50.0                      5.0
#
#     valuation requested  has patents  number of sharks in deal  \
# id
# 1                1000.0          NaN                       3.0
# 2                 267.0          NaN                       2.0
# 3                 250.0          NaN                       2.0
# 4                7000.0          NaN                       1.0
# 5                1000.0          NaN                       NaN
#
#     ashneer investment amount  aman investment amount  \
# id
# 1                        25.0                    25.0
# 2                        20.0                     NaN
# 3                         NaN                     NaN
# 4                        70.0                     NaN
# 5                         NaN                     NaN
#
#     anupam investment amount  namita investment amount  \
# id
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                       12.5                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
#
#     vineeta investment amount  ghazal investment amount  \
# id
# 1                        25.0                       NaN
# 2                        20.0                       NaN
# 3                        12.5                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
#
#     peyush investment amount  amit investment amount
# id
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# 5                        NaN                     NaN

# %%
#cleaning data

dataset['has patents'] = dataset['has patents'].fillna(False)
dataset['number of sharks in deal'] = dataset['number of sharks in deal'].fillna(0)
dataset['yearly revenue'] = dataset['number of sharks in deal'].fillna(0).map(lambda x: 0 if x <= 0 else x)
dataset['monthly sales'] = dataset['number of sharks in deal'].fillna(0).map(lambda x: 0 if x <= 0 else x)
dataset['gross margin'] = dataset['number of sharks in deal'].fillna(0).map(lambda x: 0 if x <= 0 else x)
dataset['net margin'] = dataset['number of sharks in deal'].fillna(0).map(lambda x: 0 if x <= 0 else x)
dataset['ashneer investment amount'] = dataset['ashneer investment amount'].fillna(0).map(lambda x: x > 0)
dataset['aman investment amount'] = dataset['aman investment amount'].fillna(0).map(lambda x: x > 0)
dataset['anupam investment amount'] = dataset['anupam investment amount'].fillna(0).map(lambda x: x > 0)
dataset['namita investment amount'] = dataset['namita investment amount'].fillna(0).map(lambda x: x > 0)
dataset['vineeta investment amount'] = dataset['vineeta investment amount'].fillna(0).map(lambda x: x > 0)
dataset['peyush investment amount'] = dataset['peyush investment amount'].fillna(0).map(lambda x: x > 0)
dataset['ghazal investment amount'] = dataset['ghazal investment amount'].fillna(0).map(lambda x: x > 0)
dataset['amit investment amount'] = dataset['amit investment amount'].fillna(0).map(lambda x: x > 0)

dataset.head()
# Out:
#                         industry  yearly revenue  monthly sales  gross margin  \
# id
# 1                           Food             3.0            3.0           3.0
# 2   Vehicles/Electrical Vehicles             2.0            2.0           2.0
# 3                 Beauty/Fashion             2.0            2.0           2.0
# 4                           Food             1.0            1.0           1.0
# 5                      Education             0.0            0.0           0.0
#
#     net margin  original ask amount  original offered equity  \
# id
# 1          3.0                 50.0                      5.0
# 2          2.0                 40.0                     15.0
# 3          2.0                 25.0                     10.0
# 4          1.0                 70.0                      1.0
# 5          0.0                 50.0                      5.0
#
#     valuation requested has patents  number of sharks in deal  \
# id
# 1                1000.0       False                       3.0
# 2                 267.0       False                       2.0
# 3                 250.0       False                       2.0
# 4                7000.0       False                       1.0
# 5                1000.0       False                       0.0
#
#     ashneer investment amount  aman investment amount  \
# id
# 1                        True                    True
# 2                        True                   False
# 3                       False                   False
# 4                        True                   False
# 5                       False                   False
#
#     anupam investment amount  namita investment amount  \
# id
# 1                      False                     False
# 2                      False                     False
# 3                       True                     False
# 4                      False                     False
# 5                      False                     False
#
#     vineeta investment amount  ghazal investment amount  \
# id
# 1                        True                     False
# 2                        True                     False
# 3                        True                     False
# 4                       False                     False
# 5                       False                     False
#
#     peyush investment amount  amit investment amount
# id
# 1                      False                   False
# 2                      False                   False
# 3                      False                   False
# 4                      False                   False
# 5                      False                   False

# %%
#preprocessing

X = dataset[[
    'industry',
    'yearly revenue',
    'monthly sales',
    'gross margin',
    'net margin',
    'original ask amount',
    'original offered equity',
    'valuation requested',
    'has patents'
]]
industry_dummies = pd.get_dummies(dataset['industry'], prefix='industry')
X = pd.concat([X, industry_dummies], axis=1)
X = X.drop(['industry'], axis=1)
X_scaled = MinMaxScaler(feature_range=(0, 1)).fit_transform(X)

y = dataset[[
    'number of sharks in deal',
    'ashneer investment amount',
    'aman investment amount',
    'anupam investment amount',
    'namita investment amount',
    'vineeta investment amount',
    'ghazal investment amount',
    'peyush investment amount',
    'amit investment amount',
]]

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

# %%
pd.DataFrame(y_test)
# Out:
#      number of sharks in deal  ashneer investment amount  \
# id
# 73                        1.0                      False
# 46                        3.0                      False
# 318                       2.0                      False
# 195                       2.0                      False
# 120                       0.0                      False
# ..                        ...                        ...
# 229                       1.0                      False
# 267                       1.0                      False
# 102                       1.0                      False
# 66                        3.0                       True
# 218                       1.0                      False
#
#      aman investment amount  anupam investment amount  \
# id
# 73                     True                     False
# 46                     True                      True
# 318                    True                     False
# 195                    True                     False
# 120                   False                     False
# ..                      ...                       ...
# 229                    True                     False
# 267                   False                     False
# 102                    True                     False
# 66                     True                     False
# 218                   False                      True
#
#      namita investment amount  vineeta investment amount  \
# id
# 73                      False                      False
# 46                       True                      False
# 318                     False                      False
# 195                     False                      False
# 120                     False                      False
# ..                        ...                        ...
# 229                     False                      False
# 267                     False                      False
# 102                     False                      False
# 66                      False                       True
# 218                     False                      False
#
#      ghazal investment amount  peyush investment amount  \
# id
# 73                      False                     False
# 46                      False                     False
# 318                     False                     False
# 195                     False                      True
# 120                     False                     False
# ..                        ...                       ...
# 229                     False                     False
# 267                     False                     False
# 102                     False                     False
# 66                      False                     False
# 218                     False                     False
#
#      amit investment amount
# id
# 73                    False
# 46                    False
# 318                   False
# 195                   False
# 120                   False
# ..                      ...
# 229                   False
# 267                    True
# 102                   False
# 66                    False
# 218                   False
#
# [64 rows x 9 columns]

# %%
model = MultiOutputRegressor(LogisticRegression())
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.23213126983823018

# %%
pickle.dump(model, open('shark_tank_india_model.sav', 'wb'))
